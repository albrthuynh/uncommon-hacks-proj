# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import requests
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager
import os
from collections import Counter
import squarify

# %%
api_key_kaveh = 'JRLl3R4GkcNCPAmwzo4vfUIfwttQbJlcv3ghqaJg'

# %%
# Sample query lists
original_list = ["ENFUVIRTIDE", "VALCYTE"]
drug_query_list = ['FLUOXETINE', 'PHENELZINE']
# Our base url
adverse_events_url = "https://api.fda.gov/drug/event.json?"
# Filter category
medicinal_product = "patient.drug.medicinalproduct"

# %%
def create_url(query_list, base_url, api_key, filter_category, query_limit=1000):
    list_length = len(query_list)
    url_plus_api = f"{base_url}api_key={api_key}&search="
    
    for term in query_list:
        url_plus_api += filter_category + f':"{term}"'
        list_length -= 1
        if list_length != 0:
            url_plus_api += "+AND+"
            
    url_plus_api_plus_filter = url_plus_api + f"&limit={query_limit}"

    return url_plus_api_plus_filter

# %%
fluoxetine = create_url(drug_query_list, adverse_events_url, api_key_kaveh, medicinal_product)

# %%
def get_and_validate_response(url):
    response = requests.get(url)
    if response.status_code == 200:
        print("Success!")
        return response
    else:
        print("Fail")
        return None

# %%
data_json = get_and_validate_response(fluoxetine).json()
results = data_json.get('results', [])
# Out:
# Success!

# %%
df = pd.json_normalize(results)

# %%
df.head(5)
# Out:
#   safetyreportversion safetyreportid primarysourcecountry occurcountry  \
# 0                   1       10235075                   US           US
# 1                   5       10726369                   US           US
# 2                   1       14276293                   US           US
# 3                   2       15685235                   IE           IE
# 4                   3       15724405                   IE           IE
#
#   transmissiondateformat transmissiondate reporttype serious  \
# 0                    102         20141212          1       2
# 1                    102         20170829          1       2
# 2                    102         20180321          1       1
# 3                    102         20190417          1       1
# 4                    102         20191004          1       1
#
#   receivedateformat receivedate receiptdateformat receiptdate  \
# 0               102    20140613               102    20140613
# 1               102    20150121               102    20170524
# 2               102    20171211               102    20171211
# 3               102    20181204               102    20190305
# 4               102    20181214               102    20190814
#
#   fulfillexpeditecriteria                 companynumb duplicate  \
# 0                       2  US-009507513-1406USA003372         1
# 1                       2    US-PFIZER INC-2015019537         1
# 2                       1       US-OTSUKA-2016_005097         1
# 3                       1  IE-009507513-1811IRL011820         1
# 4                       1    IE-BAUSCH-BL-2018-034714         1
#
#   reportduplicate.duplicatesource reportduplicate.duplicatenumb  \
# 0                           MERCK    US-009507513-1406USA003372
# 1                          PFIZER      US-PFIZER INC-2015019537
# 2                          OTSUKA         US-OTSUKA-2016_005097
# 3                           MERCK    IE-009507513-1811IRL011820
# 4                 BAUSCH AND LOMB      IE-BAUSCH-BL-2018-034714
#
#   primarysource.reportercountry primarysource.qualification sender.sendertype  \
# 0                            US                           1                 2
# 1                            US                           5                 2
# 2                            US                           5                 2
# 3                            IE                           1                 2
# 4                            IE                           1                 2
#
#   sender.senderorganization receiver.receivertype  \
# 0            FDA-Public Use                     6
# 1            FDA-Public Use                     6
# 2            FDA-Public Use                     6
# 3            FDA-Public Use                     6
# 4            FDA-Public Use                     6
#
#   receiver.receiverorganization patient.patientonsetage  \
# 0                           FDA                      82
# 1                           FDA                     NaN
# 2                           FDA                     NaN
# 3                           FDA                      55
# 4                           FDA                      55
#
#   patient.patientonsetageunit patient.patientsex  \
# 0                         801                  1
# 1                         NaN                  2
# 2                         NaN                  1
# 3                         801                  2
# 4                         801                  2
#
#                                     patient.reaction  \
# 0  [{'reactionmeddraversionpt': '17.0', 'reaction...
# 1  [{'reactionmeddraversionpt': '20.0', 'reaction...
# 2  [{'reactionmeddraversionpt': '20.1', 'reaction...
# 3  [{'reactionmeddraversionpt': '21.1', 'reaction...
# 4  [{'reactionmeddraversionpt': '22.0', 'reaction...
#
#                                         patient.drug  \
# 0  [{'drugcharacterization': '1', 'medicinalprodu...
# 1  [{'drugcharacterization': '1', 'medicinalprodu...
# 2  [{'drugcharacterization': '2', 'medicinalprodu...
# 3  [{'drugcharacterization': '1', 'medicinalprodu...
# 4  [{'drugcharacterization': '1', 'medicinalprodu...
#
#   seriousnesshospitalization seriousnessdisabling  \
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                          1                    1
# 3                          1                  NaN
# 4                          1                  NaN
#
#                    primarysource.literaturereference patient.patientagegroup  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3  O^LEARY J, PURCELL A, HYNES C, HUET J, ROMANOS...                     NaN
# 4  O^LEARY J, PURCELL A, HYNES C, HUET J, ROMANOS...                     NaN
#
#   seriousnessother seriousnessdeath seriousnesslifethreatening  \
# 0              NaN              NaN                        NaN
# 1              NaN              NaN                        NaN
# 2              NaN              NaN                        NaN
# 3              NaN              NaN                        NaN
# 4              NaN              NaN                        NaN
#
#   seriousnesscongenitalanomali patient.summary.narrativeincludeclinical
# 0                          NaN                                      NaN
# 1                          NaN                                      NaN
# 2                          NaN                                      NaN
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN

# %%
df1 = df.copy()

# %%
# Extract serious column names
serious_cols = []
for col in df1.columns:
    if re.search("serious", col):
        serious_cols.append(col)

print(serious_cols)
# Out:
# ['serious', 'seriousnesshospitalization', 'seriousnessdisabling', 'seriousnessother', 'seriousnessdeath', 'seriousnesslifethreatening', 'seriousnesscongenitalanomali']

# %%
top_features = [
    "patient.patientsex",
    "patient.patientonsetage",
    "patient.drug",
    "patient.reaction"
]

for col in serious_cols:
    top_features.append(col)

df1 = df1[top_features]

df1['drug_info'] = df1['patient.drug'].apply(
    lambda drugs: [(d.get('medicinalproduct'), d.get('drugcharacterization')) for d in drugs])

df1['observed_reactions'] = df1['patient.reaction'].apply(
    lambda reactions: [reaction.get('reactionmeddrapt') for reaction in reactions])

# %%
drop_cols = ['patient.drug', 'patient.reaction']
df2 = df1.copy()
df2 = df2.drop(drop_cols, axis=1)
df2.head()
# Out:
#   patient.patientsex patient.patientonsetage serious  \
# 0                  1                      82       2
# 1                  2                     NaN       2
# 2                  1                     NaN       1
# 3                  2                      55       1
# 4                  2                      55       1
#
#   seriousnesshospitalization seriousnessdisabling seriousnessother  \
# 0                        NaN                  NaN              NaN
# 1                        NaN                  NaN              NaN
# 2                          1                    1              NaN
# 3                          1                  NaN              NaN
# 4                          1                  NaN              NaN
#
#   seriousnessdeath seriousnesslifethreatening seriousnesscongenitalanomali  \
# 0              NaN                        NaN                          NaN
# 1              NaN                        NaN                          NaN
# 2              NaN                        NaN                          NaN
# 3              NaN                        NaN                          NaN
# 4              NaN                        NaN                          NaN
#
#                                            drug_info  \
# 0  [(MIRTAZAPINE, 1), (DIAZEPAM, 1), (FLUOXETINE,...
# 1  [(ATROPINE SULFATE., 1), (BELLERGAL-S, 1), (EL...
# 2  [(LITHIUM., 2), (PHENELZINE SULFATE., 2), (PRO...
# 3  [(AMITRIPTYLINE HYDROCHLORIDE., 1), (PHENELZIN...
# 4  [(SERTRALINE HYDROCHLORIDE., 1), (DULOXETINE H...
#
#           observed_reactions
# 0         [Drug ineffective]
# 1    [Drug hypersensitivity]
# 2  [Off label use, Agraphia]
# 3    [Therapy non-responder]
# 4    [Therapy non-responder]

# %%
# converting patientonsetage to integer
def integer_conversion(str_input):
    if pd.notna(str_input):
        return int(str_input)
    else:
        return np.nan

def serious_conversion(str_input):
    if pd.notna(str_input):
        return int(str_input)
    else:
        return 0
    
df3 = df2.copy()

select_cols = list(df3.columns)[:2]

for col in select_cols:
    df3[col] = df3[col].apply(integer_conversion)

for col in serious_cols:
    df3[col] = df3[col].apply(serious_conversion)

df3['patient.patientonsetage'] = df3['patient.patientonsetage'].fillna(df3['patient.patientonsetage'].median())

df3.head()
# Out:
#    patient.patientsex  patient.patientonsetage  serious  \
# 0                   1                     82.0        2
# 1                   2                     43.0        2
# 2                   1                     43.0        1
# 3                   2                     55.0        1
# 4                   2                     55.0        1
#
#    seriousnesshospitalization  seriousnessdisabling  seriousnessother  \
# 0                           0                     0                 0
# 1                           0                     0                 0
# 2                           1                     1                 0
# 3                           1                     0                 0
# 4                           1                     0                 0
#
#    seriousnessdeath  seriousnesslifethreatening  seriousnesscongenitalanomali  \
# 0                 0                           0                             0
# 1                 0                           0                             0
# 2                 0                           0                             0
# 3                 0                           0                             0
# 4                 0                           0                             0
#
#                                            drug_info  \
# 0  [(MIRTAZAPINE, 1), (DIAZEPAM, 1), (FLUOXETINE,...
# 1  [(ATROPINE SULFATE., 1), (BELLERGAL-S, 1), (EL...
# 2  [(LITHIUM., 2), (PHENELZINE SULFATE., 2), (PRO...
# 3  [(AMITRIPTYLINE HYDROCHLORIDE., 1), (PHENELZIN...
# 4  [(SERTRALINE HYDROCHLORIDE., 1), (DULOXETINE H...
#
#           observed_reactions
# 0         [Drug ineffective]
# 1    [Drug hypersensitivity]
# 2  [Off label use, Agraphia]
# 3    [Therapy non-responder]
# 4    [Therapy non-responder]

# %%
font_path = os.path.join(
    os.path.expanduser("~"),
    "uncommon-hacks-proj",
    "adversacare",
    "src",
    "assets",
    "Albert_Sans",
    "static",
    "AlbertSans-Bold.ttf"
)

font_prop = font_manager.FontProperties(fname=font_path)

# %%
# Clean and prepare seriousness dataframe
df_seriousness = df3.copy()
df_seriousness = df_seriousness[serious_cols]

if 'serious' in df_seriousness.columns:
    df_seriousness = df_seriousness.drop('serious', axis=1)

# Clean up column names
df_seriousness.columns = df_seriousness.columns.str.replace(r'^seriousness', '', regex=True)

# Count non-zero values per seriousness category
seriousness_counts = (df_seriousness != 0).sum()
seriousness_counts = seriousness_counts[seriousness_counts > 0]

# Convert to percentages and sort descending
seriousness_pct = (seriousness_counts / seriousness_counts.sum()).sort_values(ascending=False)

# Load custom font
font_path = os.path.join(
    os.getcwd(),
    "adversacare",
    "src",
    "assets",
    "Albert_Sans",
    "AlbertSans-VariableFont_wght.ttf"
)

if not os.path.isfile(font_path):
    raise FileNotFoundError(f"Font not found at: {font_path}")

font_prop = font_manager.FontProperties(fname=font_path)

# Set seaborn style
sns.set_theme()

# Color palette
colors = sns.color_palette("viridis", n_colors=len(seriousness_pct))

# Plot pie chart
fig, ax = plt.subplots(figsize=(7, 7))
wedges, texts, autotexts = ax.pie(
    seriousness_pct,
    labels=seriousness_pct.index,
    autopct=lambda p: f'{int(round(p))}%',
    startangle=140,
    colors=colors,
    textprops={'fontsize': 14, 'fontproperties': font_prop}
)

# Style inner text
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontsize(14)
    autotext.set_fontproperties(font_prop)

# Title
ax.set_title(
    "Percentage of Adverse Events by Seriousness Category",
    fontsize=18,
    fontweight='bold',
    fontproperties=font_prop
)

ax.axis('equal')  # keep the pie circular
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame: Replace this with your actual DataFrame
# df3 = pd.read_csv('your_data.csv')

# List of drugs to highlight
key_drugs = set(drug_query_list)  # Using a set for faster lookup

# Characterization labels
char_labels = {
    1: "1: Suspect",
    2: "2: Concomitant",
    3: "3: Interacting"
}

# Extract and clean drug information
rows = []
for drug_list in df3['drug_info']:
    if isinstance(drug_list, list):
        for drug_name, char_score in drug_list:
            clean_name = drug_name.strip().rstrip('.')
            label = clean_name if clean_name in key_drugs else "Other"
            rows.append((label, int(char_score)))

# Create DataFrame from extracted data
flat_df = pd.DataFrame(rows, columns=["Drug", "Char_Score"])

# Aggregate counts for each (Char_Score, Drug) pair
grouped = flat_df.groupby(['Char_Score', 'Drug']).size().unstack(fill_value=0)

# Sort drugs by total mentions in ascending order
grouped = grouped[grouped.sum(axis=0).sort_values().index]

# Plotting
plt.figure(figsize=(12, 8))
ax = grouped.plot(kind='bar', stacked=True, colormap='viridis_r', ax=plt.gca())

# Customize x-axis labels
ax.set_xticklabels([char_labels.get(i, str(i)) for i in grouped.index], rotation=0, fontsize=12)

# Set plot title and axis labels
ax.set_title("Distribution of Drugs by Characterization Score", fontsize=16)
ax.set_xlabel("Characterization Score", fontsize=14)
ax.set_ylabel("Count of Mentions", fontsize=14)

# Adjust legend
ax.legend(title="Drug", fontsize=10, title_fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Flatten the list of lists containing observed reactions
all_reactions = [reaction for sublist in df3['observed_reactions'] for reaction in sublist]

# Count the frequency of each reaction
reaction_counts = Counter(all_reactions)

# Convert to DataFrame for easier manipulation
reaction_df = pd.DataFrame(reaction_counts.items(), columns=['Reaction', 'Frequency'])

# Sort by frequency and select the top 10 reactions
top_reactions = reaction_df.nlargest(10, 'Frequency')

# Define a function to wrap text labels
def wrap_label(label, max_chars):
    """Wrap text by inserting newline characters at spaces, ensuring no line exceeds max_chars."""
    words = label.split()
    wrapped_label = ''
    line = ''
    for word in words:
        if len(line) + len(word) + 1 <= max_chars:
            line += (word + ' ')
        else:
            wrapped_label += line.rstrip() + '\n'
            line = word + ' '
    wrapped_label += line.rstrip()
    return wrapped_label

# Apply the wrapping function to each reaction label
max_chars_per_line = 10  # Adjust based on your treemap box sizes
top_reactions['Wrapped_Label'] = top_reactions['Reaction'].apply(lambda x: wrap_label(x, max_chars_per_line))

# Prepare data for plotting
sizes = top_reactions['Frequency']
labels = top_reactions['Wrapped_Label']

# Generate colors from the 'viridis' palette
palette = sns.color_palette('viridis', n_colors=14)
colors = palette[:len(sizes)]

# Create the treemap
plt.figure(figsize=(12, 8))
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=0.7, text_kwargs={'fontsize': 18, 'color': 'white'})
plt.axis('off')
plt.title('Top 10 Observed Reactions Across Different Drugs', fontsize=20)
plt.show()
