# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import requests
import re
import numpy as np

# %%
api_key = 'JRLl3R4GkcNCPAmwzo4vfUIfwttQbJlcv3ghqaJg'

# %%
url = f'https://api.fda.gov/drug/event.json?api_key={api_key}&search=patient.drug.medicinalproduct:"ENFUVIRTIDE"+AND+patient.drug.medicinalproduct:"VALCYTE"&limit=10'

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
results = data.get('results', [])

# %%
df = pd.json_normalize(results)

# %%
df.head(10)
# Out:
#   safetyreportid transmissiondateformat transmissiondate serious  \
# 0      4332068-5                    102         20050107       1
# 1      4313623-5                    102         20041129       1
# 2      4661719-0                    102         20051028       1
# 3      5395349-2                    102         20080115       1
# 4      6251992-X                    102         20091009       1
# 5      6251998-0                    102         20091009       1
# 6      6252001-9                    102         20091009       1
# 7      6252033-0                    102         20091009       1
# 8      6252034-2                    102         20091009       1
# 9      6252137-2                    102         20091009       1
#
#   seriousnesshospitalization receivedateformat receivedate receiptdateformat  \
# 0                          1               102    20040405               102
# 1                          1               102    20040305               102
# 2                          1               102    20050513               102
# 3                          1               102    20070724               102
# 4                          1               102    20090630               102
# 5                          1               102    20090630               102
# 6                          1               102    20090630               102
# 7                          1               102    20090630               102
# 8                          1               102    20090630               102
# 9                          1               102    20090630               102
#
#   receiptdate fulfillexpeditecriteria                   companynumb receiver  \
# 0    20030905                       1               FR-ROCHE-346272     None
# 1    20040223                       1            03P-163-0234177-00     None
# 2    20041019                       1               US-ROCHE-383715     None
# 3    20070719                       1  US-ABBOTT-03P-163-0234177-00     None
# 4    20050202                       1               US-ROCHE-638337     None
# 5    20040715                       1               US-ROCHE-638353     None
# 6    20041229                       1               US-ROCHE-638386     None
# 7    20070414                       1               US-ROCHE-638600     None
# 8    20041111                       1               US-ROCHE-638662     None
# 9    20041111                       1               US-ROCHE-639206     None
#
#   primarysource.qualification sender.senderorganization  \
# 0                           1            FDA-Public Use
# 1                           1            FDA-Public Use
# 2                           1            FDA-Public Use
# 3                         NaN            FDA-Public Use
# 4                           1            FDA-Public Use
# 5                           1            FDA-Public Use
# 6                           1            FDA-Public Use
# 7                           1            FDA-Public Use
# 8                           1            FDA-Public Use
# 9                           1            FDA-Public Use
#
#   patient.patientonsetage patient.patientonsetageunit patient.patientweight  \
# 0                      48                         801                    79
# 1                      42                         801                   NaN
# 2                      55                         801                  62.6
# 3                     NaN                         NaN                   NaN
# 4                     NaN                         NaN                   NaN
# 5                     NaN                         NaN                   NaN
# 6                     NaN                         NaN                   NaN
# 7                     NaN                         NaN                   NaN
# 8                     NaN                         NaN                   NaN
# 9                     NaN                         NaN                   NaN
#
#   patient.patientsex                                   patient.reaction  \
# 0                  1  [{'reactionmeddrapt': 'COUGH'}, {'reactionmedd...
# 1                  1  [{'reactionmeddrapt': 'KAPOSI'S SARCOMA'}, {'r...
# 2                  1  [{'reactionmeddrapt': 'ANAEMIA'}, {'reactionme...
# 3                  1  [{'reactionmeddrapt': 'PNEUMONIA'}, {'reaction...
# 4                  1  [{'reactionmeddrapt': 'ANAEMIA'}, {'reactionme...
# 5                  1  [{'reactionmeddrapt': 'CACHEXIA'}, {'reactionm...
# 6                  1  [{'reactionmeddrapt': 'UPPER RESPIRATORY TRACT...
# 7                  2  [{'reactionmeddrapt': 'PNEUMOCYSTIS JIROVECI P...
# 8                  1  [{'reactionmeddrapt': 'CYTOMEGALOVIRUS COLITIS'}]
# 9                  1  [{'reactionmeddrapt': 'DEHYDRATION'}, {'reacti...
#
#                                         patient.drug seriousnessdeath  \
# 0  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 1  [{'drugcharacterization': '1', 'medicinalprodu...                1
# 2  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 3  [{'drugcharacterization': '1', 'medicinalprodu...                1
# 4  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 5  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 6  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 7  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 8  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
# 9  [{'drugcharacterization': '1', 'medicinalprodu...              NaN
#
#   seriousnessdisabling  patient.patientdeath.patientdeathdateformat  \
# 0                  NaN                                          NaN
# 1                    1                                          NaN
# 2                  NaN                                          NaN
# 3                    1                                          NaN
# 4                  NaN                                          NaN
# 5                  NaN                                          NaN
# 6                  NaN                                          NaN
# 7                  NaN                                          NaN
# 8                  NaN                                          NaN
# 9                  NaN                                          NaN
#
#    patient.patientdeath.patientdeathdate primarysource.reportercountry
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                 UNITED STATES
# 4                                    NaN                 UNITED STATES
# 5                                    NaN                 UNITED STATES
# 6                                    NaN                 UNITED STATES
# 7                                    NaN                 UNITED STATES
# 8                                    NaN                 UNITED STATES
# 9                                    NaN                 UNITED STATES

# %%
df1 = df.copy()

# %%
# Extract serious column names
serious_cols = []
for col in df1.columns:
    if re.search("serious", col):
        serious_cols.append(col)

print(serious_cols)
# Out:
# ['serious', 'seriousnesshospitalization', 'seriousnessdeath', 'seriousnessdisabling']

# %%
top_features = [
    "patient.patientsex",
    "patient.patientonsetage",
    "patient.drug",
    "patient.reaction"
]

for col in serious_cols:
    top_features.append(col)

df1 = df1[top_features]

df1['drug_info'] = df1['patient.drug'].apply(
    lambda drugs: [(d.get('medicinalproduct'), d.get('drugcharacterization')) for d in drugs])

df1['observed_reactions'] = df1['patient.reaction'].apply(
    lambda reactions: [reaction.get('reactionmeddrapt') for reaction in reactions])

# %%
drop_cols = ['patient.drug', 'patient.reaction']
df2 = df1.copy()
df2 = df2.drop(drop_cols, axis=1)
df2
# Out:
#   patient.patientsex patient.patientonsetage serious  \
# 0                  1                      48       1
# 1                  1                      42       1
# 2                  1                      55       1
# 3                  1                     NaN       1
# 4                  1                     NaN       1
# 5                  1                     NaN       1
# 6                  1                     NaN       1
# 7                  2                     NaN       1
# 8                  1                     NaN       1
# 9                  1                     NaN       1
#
#   seriousnesshospitalization seriousnessdeath seriousnessdisabling  \
# 0                          1              NaN                  NaN
# 1                          1                1                    1
# 2                          1              NaN                  NaN
# 3                          1                1                    1
# 4                          1              NaN                  NaN
# 5                          1              NaN                  NaN
# 6                          1              NaN                  NaN
# 7                          1              NaN                  NaN
# 8                          1              NaN                  NaN
# 9                          1              NaN                  NaN
#
#                                            drug_info  \
# 0  [(ENFUVIRTIDE, 1), (EPIVIR, 2), (ATAZANAVIR, 2...
# 1  [(NORVIR, 1), (TIPRANAVIR, 2), (ABACAVIR SULFA...
# 2  [(ENFUVIRTIDE, 1), (VALCYTE, 2), (DAPSONE, 2),...
# 3  [(RITONAVIR SOFT GELATIN CAPSULES, 1), (TIPRAN...
# 4  [(ENFUVIRTIDE, 1), (INVIRASE, 2), (VIREAD, 2),...
# 5  [(ENFUVIRTIDE, 1), (VALCYTE, 2), (VALCYTE, 2),...
# 6  [(ENFUVIRTIDE, 1), (INVIRASE, 2), (VIDEX, 2), ...
# 7  [(ENFUVIRTIDE, 1), (ENFUVIRTIDE, 1), (KALETRA,...
# 8  [(ENFUVIRTIDE, 1), (ZIAGEN, 2), (VIDEX, 2), (V...
# 9  [(ENFUVIRTIDE, 1), (ZIAGEN, 2), (VIDEX, 2), (V...
#
#                                   observed_reactions
# 0  [COUGH, DYSPNOEA, FUNGUS SEROLOGY TEST POSITIV...
# 1  [KAPOSI'S SARCOMA, PNEUMONIA, RENAL FAILURE, R...
# 2  [ANAEMIA, ILEUS, PNEUMONIA PRIMARY ATYPICAL, S...
# 3  [PNEUMONIA, RENAL FAILURE, RESPIRATORY FAILURE...
# 4  [ANAEMIA, CANDIDIASIS, CYTOMEGALOVIRUS OESOPHA...
# 5  [CACHEXIA, ENCEPHALITIS CYTOMEGALOVIRUS, ENCEP...
# 6                [UPPER RESPIRATORY TRACT INFECTION]
# 7  [PNEUMOCYSTIS JIROVECI PNEUMONIA, RENAL TUBULA...
# 8                          [CYTOMEGALOVIRUS COLITIS]
# 9                           [DEHYDRATION, DIARRHOEA]

# %%
# converting patientonsetage to integer
def integer_conversion(str_input):
    if pd.notna(str_input):
        return int(str_input)
    else:
        return np.nan

def serious_conversion(str_input):
    if pd.notna(str_input):
        return int(str_input)
    else:
        return 0
    
df3 = df2.copy()

select_cols = list(df4.columns)[:2]

for col in select_cols:
    df3[col] = df3[col].apply(integer_conversion)

for col in serious_cols:
    df3[col] = df3[col].apply(serious_conversion)

df3['patient.patientonsetage'] = df3['patient.patientonsetage'].fillna(df3['patient.patientonsetage'].mean())

df3
# Out:
#    patient.patientsex  patient.patientonsetage  serious  \
# 0                   1                48.000000        1
# 1                   1                42.000000        1
# 2                   1                55.000000        1
# 3                   1                48.333333        1
# 4                   1                48.333333        1
# 5                   1                48.333333        1
# 6                   1                48.333333        1
# 7                   2                48.333333        1
# 8                   1                48.333333        1
# 9                   1                48.333333        1
#
#    seriousnesshospitalization  seriousnessdeath  seriousnessdisabling  \
# 0                           1                 0                     0
# 1                           1                 1                     1
# 2                           1                 0                     0
# 3                           1                 1                     1
# 4                           1                 0                     0
# 5                           1                 0                     0
# 6                           1                 0                     0
# 7                           1                 0                     0
# 8                           1                 0                     0
# 9                           1                 0                     0
#
#                                            drug_info  \
# 0  [(ENFUVIRTIDE, 1), (EPIVIR, 2), (ATAZANAVIR, 2...
# 1  [(NORVIR, 1), (TIPRANAVIR, 2), (ABACAVIR SULFA...
# 2  [(ENFUVIRTIDE, 1), (VALCYTE, 2), (DAPSONE, 2),...
# 3  [(RITONAVIR SOFT GELATIN CAPSULES, 1), (TIPRAN...
# 4  [(ENFUVIRTIDE, 1), (INVIRASE, 2), (VIREAD, 2),...
# 5  [(ENFUVIRTIDE, 1), (VALCYTE, 2), (VALCYTE, 2),...
# 6  [(ENFUVIRTIDE, 1), (INVIRASE, 2), (VIDEX, 2), ...
# 7  [(ENFUVIRTIDE, 1), (ENFUVIRTIDE, 1), (KALETRA,...
# 8  [(ENFUVIRTIDE, 1), (ZIAGEN, 2), (VIDEX, 2), (V...
# 9  [(ENFUVIRTIDE, 1), (ZIAGEN, 2), (VIDEX, 2), (V...
#
#                                   observed_reactions
# 0  [COUGH, DYSPNOEA, FUNGUS SEROLOGY TEST POSITIV...
# 1  [KAPOSI'S SARCOMA, PNEUMONIA, RENAL FAILURE, R...
# 2  [ANAEMIA, ILEUS, PNEUMONIA PRIMARY ATYPICAL, S...
# 3  [PNEUMONIA, RENAL FAILURE, RESPIRATORY FAILURE...
# 4  [ANAEMIA, CANDIDIASIS, CYTOMEGALOVIRUS OESOPHA...
# 5  [CACHEXIA, ENCEPHALITIS CYTOMEGALOVIRUS, ENCEP...
# 6                [UPPER RESPIRATORY TRACT INFECTION]
# 7  [PNEUMOCYSTIS JIROVECI PNEUMONIA, RENAL TUBULA...
# 8                          [CYTOMEGALOVIRUS COLITIS]
# 9                           [DEHYDRATION, DIARRHOEA]
